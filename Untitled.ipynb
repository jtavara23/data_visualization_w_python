# %%
##can not modify a figure once it's render [%matplotlib inline]
import matplotlib.pyplot as plt
import numpy as np

x = np.random.randn(10000)
plt.hist(x,100)
plt.title('histogram with $~\mu=0, \sigma=1$')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
plt.plot(5,5,'o')
plt.show()

# %%
plt.plot(5,20,'o')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">
